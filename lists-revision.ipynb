# %% [markdown]
# <a href="https://www.kaggle.com/code/prudhvi143413s/lists-revision?scriptVersionId=185418207" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# * Python LIsts are dynamic sized arrays
# * The list is a sequence Data type which is used to store the collection of data.
# * Tuples and strings are other types of datatypes which are of type sequence

# %%
var=[]
print(var)
var=['Bandaru','Prudhvi',"Narayana"]
print(var)
print(var[0])
print(var[2])
# print(var[4])
# Out:
# []
# ['Bandaru', 'Prudhvi', 'Narayana']
# Bandaru
# Narayana

# %% [markdown]
# List need not be homongenous always which makes it the powerful tool in python
# A single list may contain different datatypes like integers,strings,float,boolean etc...

# %% [markdown]
# **Complexity  for creating lists**
# * Time Complexity =o(1)
# * Space Complexity=o(n)

# %%
var
# Out:
# ['Bandaru', 'Prudhvi', 'Narayana']

# %%
name=[['Prudhvi','Naryana'],['Bandaru']]
print("The First name is =",name [0])
print("The last name is =",name[1])
# Out:
# The First name is = ['Prudhvi', 'Naryana']
# The last name is = ['Bandaru']

# %% [markdown]
# **Negitive indexing is possible to do in lists**
# * it is enough to just write List[-3] instead of List[len(List)-3]

# %% [markdown]
# **Complexity of Accessing elements from a list = o(1) both space and time complexity**
# * len() function is used to find the length of the list

# %%
my_name="Prudhvi Narayana Bandaru"
lst=my_name.split(' ')
lst
# Out:
# ['Prudhvi', 'Narayana', 'Bandaru']

# %% [markdown]
# **Adding two lists using functions**

# %%
def add(x,y):
    return x+y

# %%
lst1=[1,2,3]
lst2=[4,5,6]
res=[add(x,y) for x,y in zip(lst1,lst2)]
res
# Out:
# [5, 7, 9]

# %%
#i want to take multiple values as input 
n=int(input("Enter n value"))
inp=list(map(int,input().split()))[:n]
print(inp)
# Out:
# Enter n value 4
#  1 2 3 4 5 6 6
# [1, 2, 3, 4]

# %% [markdown]
# **List Comprehensions**

# %%
odd_square=[x**2 for x in range(15) if x%2!=0]
print(odd_square)
# Out:
# [1, 9, 25, 49, 81, 121, 169]

# %%
ls=[x for x in range(1,14)]
do=[]
def odd_square(ls):
    for i in range(len(ls)):
        if(ls[i]%2!=0):
            do.append(ls[i]**2)
    return do
odd_square(ls)
# Out:
# [1, 9, 25, 49, 81, 121, 169]

# %% [markdown]
# Compare both above codes

# %% [markdown]
# **List operations**

# %% [markdown]
# **Using Append() Method**

# %%
List = []
print("Initial blank List: ")
print(List)

# Addition of Elements
# in the List
List.append(1)
List.append(2)
List.append(4)
print("\nList after Addition of Three elements: ")
print(List)

for i in range(1,4):
    List.append(i)
print("List after adding 1-3 :")
print(List)

#adding tuples to the list
List.append((5,6))
print("List After adding the tuple: ")
print(List)
 
#adding list to the list
List2=['For','Geeks']
List.append(List2)
print("After addition of list2 =")
print(List)
# Out:
# Initial blank List:
# []
#
# List after Addition of Three elements:
# [1, 2, 4]
# List after adding 1-3 :
# [1, 2, 4, 1, 2, 3]
# List After adding the tuple:
# [1, 2, 4, 1, 2, 3, (5, 6)]
# After addition of list2 =
# [1, 2, 4, 1, 2, 3, (5, 6), ['For', 'Geeks']]

# %% [markdown]
# **Using Insert() Method**

# %% [markdown]
# **Unlike append() which takes only one argument, the insert() method requires two arguments(position, value).**

# %%
List3=[]
List3.insert(1,21)
List3.insert(0,5)
List3.insert(2,34)
List3
# Out:
# [5, 21, 34]

# %% [markdown]
# **Inserting multiple elements into the list using extend() method**

# %%
List4=['Geeks','For','Geeks']
List3.extend(List4)

# %%
List4.extend(List3)
# List4

# %% [markdown]
# **Removing the values using python remove() method**

# %%
#return method wont return anything 
lst=[1,2,3,4,5,6,7,8]
for i in range(1,5):
    lst.remove(i)
print("The list after removing the desired elements using a for-loop is : ",end= " ")
print(lst)
# Out:
# The list after removing the desired elements using a for-loop is :  [5, 6, 7, 8]

# %% [markdown]
# **Remvoing the values using Pop() method**

# %%
for i in range(0,5):
    lst.insert(i,i)
lst

x=lst.pop()
print(x)
print(lst)
lst.pop(3)
# Out:
# 8
# [0, 1, 2, 3, 4, 5, 6, 7]
# 3

# %% [markdown]
# **Reverese a list**

# %%
#method 1
mylist=[1,2,3,4,'Geeks','python']
mylist.reverse()  #here we wont get any reference or output 
mylist
# Out:
# ['python', 'Geeks', 4, 3, 2, 1]

# %%
mylist=[1,2,3,4,'Geeks','python']
mylist2=list(reversed(mylist))
print(mylist2)
# Out:
# ['python', 'Geeks', 4, 3, 2, 1]

# %%
mylist_rev=mylist[::-1]
print(mylist_rev)
# Out:
# ['python', 'Geeks', 4, 3, 2, 1]

# %% [markdown]
# **Slicing a List**

# %% [markdown]
# * We can get substrings and sublists using a slice.
# * In Python List, there are multiple ways to print the whole list with all the elements, but to print a specific range of elements from the list, we use the Slice operation.
# * Slice operation is performed on Lists with the use of a colon(:).

# %%
kst=[1,2,4,6,9]
kst[:]
kst[1:]
kst[::-1]  #reverse the list
kst[:-1]  #upto one before from first
kst[-3:]
kst[-6:]
# Out:
# [1, 2, 4, 6, 9]

# %%
# Creating a List
List_1= ['G', 'E', 'E', 'K', 'S', 'F','O', 'R', 'G', 'E', 'E', 'K', 'S']
print("The Initial List is= ",end=" ")
print(List_1)
sliced_list=List_1[:-6]
print(sliced_list)
print(List_1[-6:-1])
#reverse the list
print(List_1[::-1])
# Out:
# The Initial List is=  ['G', 'E', 'E', 'K', 'S', 'F', 'O', 'R', 'G', 'E', 'E', 'K', 'S']
# ['G', 'E', 'E', 'K', 'S', 'F', 'O']
# ['R', 'G', 'E', 'E', 'K']
# ['S', 'K', 'E', 'E', 'G', 'R', 'O', 'F', 'S', 'K', 'E', 'E', 'G']
